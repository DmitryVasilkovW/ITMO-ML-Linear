# %% [markdown]
# ### Best parameters

# %%
from linear.visualisation.lab import show_best_params_for_lab
from linear.visualisation.lab import show_plots_for_lab

show_best_params_for_lab()
# Out:
# /Users/dmitryvasilkov/PycharmProjects/3-linear-DmitryVasilkovW/linear/dataset/data.py:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.replace({'x': 1, 'o': 0, 'b': -1}, inplace=True)
# Best alpha for Ridge Regression: 0.01
# Best alpha for Logistic Regression: 0.01
# Best alpha for SVM: 0.01
# Best C for SVM: 0.1
# Best kernel: linear
# Best accuracy for Ridge Regression: 0.69
# Best accuracy for Logistic Regression: 0.65
# Best accuracy for SVM: 0.65

# %% [markdown]
# ### Plots

# %%
show_plots_for_lab()
